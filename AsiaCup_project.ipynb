# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
#Read csv file:
df=pd.read_csv('asiacup.csv')
df
# Out:
#           Team     Opponent Format      Ground  Year  Toss Selection  \
# 0     Pakistan    Sri Lanka    ODI     Sharjah  1984  Lose   Batting
# 1    Sri Lanka     Pakistan    ODI     Sharjah  1984   Win   Bowling
# 2        India    Sri Lanka    ODI     Sharjah  1984   Win   Bowling
# 3    Sri Lanka        India    ODI     Sharjah  1984  Lose   Batting
# 4        India     Pakistan    ODI     Sharjah  1984   Win   Batting
# ..         ...          ...    ...         ...   ...   ...       ...
# 249      India  Afghanistan   T20I  Dubai(DSC)  2022  Lose   Batting
# 250   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022  Lose   Batting
# 251  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022   Win   Bowling
# 252   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022   Win   Bowling
# 253  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022  Lose   Batting
#
#      Run Scored  Wicket Lost  Fours  Sixes  Extras  Run Rate  \
# 0         187.0          9.0    9.0    3.0    21.0      4.06
# 1         190.0          5.0   11.0    1.0    26.0      4.36
# 2          97.0          0.0    9.0    0.0    14.0      4.47
# 3          96.0         10.0    7.0    0.0     8.0      2.34
# 4         188.0          4.0   13.0    3.0    17.0      4.08
# ..          ...          ...    ...    ...     ...       ...
# 249       212.0          2.0   21.0    9.0     2.0     10.60
# 250       121.0         10.0    4.0    3.0    17.0      6.31
# 251       124.0          5.0    9.0    5.0     5.0      7.29
# 252       147.0         10.0    9.0    4.0    14.0      7.35
# 253       170.0          6.0   16.0    5.0    10.0      8.50
#
#      Avg Bat Strike Rate  Highest Score  Wicket Taken  Given Extras  \
# 0                  52.04           47.0           5.0          26.0
# 1                  68.51           57.0           9.0          21.0
# 2                  60.48           51.0          10.0           8.0
# 3                  25.74           38.0           0.0          14.0
# 4                  60.21           56.0          10.0           5.0
# ..                   ...            ...           ...           ...
# 249               194.05          122.0           8.0           3.0
# 250                58.78           30.0           5.0           5.0
# 251               111.50           55.0          10.0          17.0
# 252                99.38           55.0           6.0          10.0
# 253                90.86           71.0          10.0          14.0
#
#      Highest Individual wicket         Player Of The Match Result
# 0                          2.0                    Roy Dias   Lose
# 1                          3.0                    Roy Dias    Win
# 2                          3.0             Surinder Khanna    Win
# 3                          0.0             Surinder Khanna   Lose
# 4                          3.0             Surinder Khanna    Win
# ..                         ...                         ...    ...
# 249                        5.0                 Virat Kohli    Win
# 250                        2.0  Wanindu Hasaranga de Silva   Lose
# 251                        3.0  Wanindu Hasaranga de Silva    Win
# 252                        3.0           Bhanuka Rajapaksa   Lose
# 253                        4.0           Bhanuka Rajapaksa    Win
#
# [254 rows x 20 columns]

# %%
#displaying numerical and categorical column:
num_col=df.select_dtypes(["int","float"]).columns
num_col
# Out:
# Index(['Year', 'Run Scored', 'Wicket Lost', 'Fours', 'Sixes', 'Extras',
#        'Run Rate', 'Avg Bat Strike Rate', 'Highest Score', 'Wicket Taken',
#        'Given Extras', 'Highest Individual wicket'],
#       dtype='object')

# %%
cat_col=df.select_dtypes(['O']).columns
cat_col
# Out:
# Index(['Team', 'Opponent', 'Format', 'Ground', 'Toss', 'Selection',
#        'Player Of The Match', 'Result'],
#       dtype='object')

# %% [markdown]
# Q1.Display first 10 record of dataset:

# %%
df.head(10)
# Out:
#          Team    Opponent Format        Ground  Year  Toss Selection  \
# 0    Pakistan   Sri Lanka    ODI       Sharjah  1984  Lose   Batting
# 1   Sri Lanka    Pakistan    ODI       Sharjah  1984   Win   Bowling
# 2       India   Sri Lanka    ODI       Sharjah  1984   Win   Bowling
# 3   Sri Lanka       India    ODI       Sharjah  1984  Lose   Batting
# 4       India    Pakistan    ODI       Sharjah  1984   Win   Batting
# 5    Pakistan       India    ODI       Sharjah  1984  Lose   Bowling
# 6   Sri Lanka    Pakistan    ODI  Colombo(PSS)  1986   Win   Bowling
# 7    Pakistan   Sri Lanka    ODI  Colombo(PSS)  1986  Lose   Batting
# 8  Bangladesh    Pakistan    ODI      Moratuwa  1986  Lose   Batting
# 9    Pakistan  Bangladesh    ODI      Moratuwa  1986   Win   Bowling
#
#    Run Scored  Wicket Lost  Fours  Sixes  Extras  Run Rate  \
# 0       187.0          9.0    9.0    3.0    21.0      4.06
# 1       190.0          5.0   11.0    1.0    26.0      4.36
# 2        97.0          0.0    9.0    0.0    14.0      4.47
# 3        96.0         10.0    7.0    0.0     8.0      2.34
# 4       188.0          4.0   13.0    3.0    17.0      4.08
# 5       134.0         10.0    5.0    0.0     5.0      3.37
# 6       116.0         10.0   10.0    0.0    14.0      3.42
# 7       197.0         10.0   14.0    3.0    15.0      4.37
# 8        94.0         10.0    0.0    0.0     9.0      2.64
# 9        98.0          3.0    4.0    0.0     5.0      3.04
#
#    Avg Bat Strike Rate  Highest Score  Wicket Taken  Given Extras  \
# 0                52.04           47.0           5.0          26.0
# 1                68.51           57.0           9.0          21.0
# 2                60.48           51.0          10.0           8.0
# 3                25.74           38.0           0.0          14.0
# 4                60.21           56.0          10.0           5.0
# 5                39.46           35.0           4.0          17.0
# 6                37.87           34.0          10.0          15.0
# 7                65.14           39.0          10.0          14.0
# 8                24.63           37.0           3.0           5.0
# 9                36.79           47.0          10.0           9.0
#
#    Highest Individual wicket Player Of The Match Result
# 0                        2.0            Roy Dias   Lose
# 1                        3.0            Roy Dias    Win
# 2                        3.0     Surinder Khanna    Win
# 3                        0.0     Surinder Khanna   Lose
# 4                        3.0     Surinder Khanna    Win
# 5                        1.0     Surinder Khanna   Lose
# 6                        3.0         Mohsin Khan   Lose
# 7                        3.0         Mohsin Khan    Win
# 8                        2.0         Wasim Akram   Lose
# 9                        4.0         Wasim Akram    Win

# %% [markdown]
# Q2.Display last 10 record of dataset:

# %%
df.tail()
# Out:
#           Team     Opponent Format      Ground  Year  Toss Selection  \
# 249      India  Afghanistan   T20I  Dubai(DSC)  2022  Lose   Batting
# 250   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022  Lose   Batting
# 251  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022   Win   Bowling
# 252   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022   Win   Bowling
# 253  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022  Lose   Batting
#
#      Run Scored  Wicket Lost  Fours  Sixes  Extras  Run Rate  \
# 249       212.0          2.0   21.0    9.0     2.0     10.60
# 250       121.0         10.0    4.0    3.0    17.0      6.31
# 251       124.0          5.0    9.0    5.0     5.0      7.29
# 252       147.0         10.0    9.0    4.0    14.0      7.35
# 253       170.0          6.0   16.0    5.0    10.0      8.50
#
#      Avg Bat Strike Rate  Highest Score  Wicket Taken  Given Extras  \
# 249               194.05          122.0           8.0           3.0
# 250                58.78           30.0           5.0           5.0
# 251               111.50           55.0          10.0          17.0
# 252                99.38           55.0           6.0          10.0
# 253                90.86           71.0          10.0          14.0
#
#      Highest Individual wicket         Player Of The Match Result
# 249                        5.0                 Virat Kohli    Win
# 250                        2.0  Wanindu Hasaranga de Silva   Lose
# 251                        3.0  Wanindu Hasaranga de Silva    Win
# 252                        3.0           Bhanuka Rajapaksa   Lose
# 253                        4.0           Bhanuka Rajapaksa    Win

# %% [markdown]
# Q3.Find the shape of Dataset(Number of rows and columns):

# %%
df.shape
print("Number of Rows:",df.shape[0])
print("Number of columns:",df.shape[1])
# Out:
# Number of Rows: 254
# Number of columns: 20

# %% [markdown]
# Q4) Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Team                       254 non-null    object
#  1   Opponent                   254 non-null    object
#  2   Format                     254 non-null    object
#  3   Ground                     254 non-null    object
#  4   Year                       254 non-null    int64
#  5   Toss                       254 non-null    object
#  6   Selection                  254 non-null    object
#  7   Run Scored                 252 non-null    float64
#  8   Wicket Lost                252 non-null    float64
#  9   Fours                      252 non-null    float64
#  10  Sixes                      252 non-null    float64
#  11  Extras                     252 non-null    float64
#  12  Run Rate                   252 non-null    float64
#  13  Avg Bat Strike Rate        252 non-null    float64
#  14  Highest Score              252 non-null    float64
#  15  Wicket Taken               252 non-null    float64
#  16  Given Extras               252 non-null    float64
#  17  Highest Individual wicket  252 non-null    float64
#  18  Player Of The Match        252 non-null    object
#  19  Result                     254 non-null    object
# dtypes: float64(11), int64(1), object(8)
# memory usage: 39.8+ KB

# %%
# We can observe that our dataset contains 254 rows and 20 columns.
# We also observe that there are 12 columns of integer datatype,
# and 8 columns of object datatype.

# %% [markdown]
# Q5) Check for missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# Team                         0
# Opponent                     0
# Format                       0
# Ground                       0
# Year                         0
# Toss                         0
# Selection                    0
# Run Scored                   2
# Wicket Lost                  2
# Fours                        2
# Sixes                        2
# Extras                       2
# Run Rate                     2
# Avg Bat Strike Rate          2
# Highest Score                2
# Wicket Taken                 2
# Given Extras                 2
# Highest Individual wicket    2
# Player Of The Match          2
# Result                       0
# dtype: int64

# %%
df.dropna(inplace=True,axis=1)
df
# Out:
#           Team     Opponent Format      Ground  Year  Toss Selection Result
# 0     Pakistan    Sri Lanka    ODI     Sharjah  1984  Lose   Batting   Lose
# 1    Sri Lanka     Pakistan    ODI     Sharjah  1984   Win   Bowling    Win
# 2        India    Sri Lanka    ODI     Sharjah  1984   Win   Bowling    Win
# 3    Sri Lanka        India    ODI     Sharjah  1984  Lose   Batting   Lose
# 4        India     Pakistan    ODI     Sharjah  1984   Win   Batting    Win
# ..         ...          ...    ...         ...   ...   ...       ...    ...
# 249      India  Afghanistan   T20I  Dubai(DSC)  2022  Lose   Batting    Win
# 250   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022  Lose   Batting   Lose
# 251  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022   Win   Bowling    Win
# 252   Pakistan    Sri Lanka   T20I  Dubai(DSC)  2022   Win   Bowling   Lose
# 253  Sri Lanka     Pakistan   T20I  Dubai(DSC)  2022  Lose   Batting    Win
#
# [254 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Team         0
# Opponent     0
# Format       0
# Ground       0
# Year         0
# Toss         0
# Selection    0
# Result       0
# dtype: int64

# %% [markdown]
# Q7) Get overall statistics about the dataframe.

# %%
df.describe()
# Out:
#               Year
# count   254.000000
# mean   2006.905512
# std      11.014495
# min    1984.000000
# 25%    1997.750000
# 50%    2008.000000
# 75%    2016.000000
# max    2022.000000

# %%
#we observe that year column is left skewed,as medain is greator than mean:
sns.distplot(df['Year'],color='r')
plt.show()

# %%
cat_col=df.select_dtypes(['O']).columns
cat_col
# Out:
# Index(['Team', 'Opponent', 'Format', 'Ground', 'Toss', 'Selection', 'Result'], dtype='object')

# %%
df['Team'].unique()
# Out:
# array(['Pakistan', 'Sri Lanka', 'India', 'Bangladesh', 'Hong Kong', 'UAE',
#        'Afghanistan'], dtype=object)

# %% [markdown]
# Q8 show the percentage of the format played in asia cup:

# %%
df['Format'].value_counts().plot(kind='pie',autopct="%.2f%%")
# Out:
# <Axes: ylabel='Format'>

# %% [markdown]
# Q10.Display percentage of  most winner no of matches:

# %%
df['Team'].value_counts().plot(kind='pie',autopct="%.2f%%")
# Out:
# <Axes: ylabel='Team'>

# %% [markdown]
# Q11 Display All mathes of india:

# %%
df[df['Team'].str.contains("India")]
# Out:
#       Team     Opponent Format        Ground  Year  Toss Selection     Result
# 2    India    Sri Lanka    ODI       Sharjah  1984   Win   Bowling        Win
# 4    India     Pakistan    ODI       Sharjah  1984   Win   Batting        Win
# 17   India   Bangladesh    ODI    Chattogram  1988   Win   Bowling        Win
# 168  India     Pakistan    ODI        Mirpur  2014  Lose   Batting       Lose
# 175  India  Afghanistan    ODI        Mirpur  2014   Win   Bowling        Win
# 181  India   Bangladesh   T20I        Mirpur  2016  Lose   Batting        Win
# 186  India     Pakistan   T20I        Mirpur  2016   Win   Bowling        Win
# 192  India    Sri Lanka   T20I        Mirpur  2016   Win   Bowling        Win
# 196  India          UAE   T20I        Mirpur  2016  Lose   Bowling        Win
# 201  India   Bangladesh   T20I        Mirpur  2016   Win   Bowling        Win
# 209  India    Hong Kong    ODI    Dubai(DSC)  2018  Lose   Batting        Win
# 210  India     Pakistan    ODI    Dubai(DSC)  2018  Lose   Bowling        Win
# 215  India   Bangladesh    ODI    Dubai(DSC)  2018   Win   Bowling        Win
# 218  India     Pakistan    ODI    Dubai(DSC)  2018  Lose   Bowling        Win
# 223  India  Afghanistan    ODI    Dubai(DSC)  2018  Lose   Bowling  No Result
# 227  India   Bangladesh    ODI    Dubai(DSC)  2018   Win   Bowling        Win
# 230  India     Pakistan   T20I    Dubai(DSC)  2022   Win   Bowling        Win
# 235  India    Hong Kong   T20I    Dubai(DSC)  2022  Lose   Batting        Win
# 242  India     Pakistan   T20I    Dubai(DSC)  2022  Lose   Batting       Lose
# 244  India    Sri Lanka   T20I    Dubai(DSC)  2022  Lose   Batting       Lose
# 249  India  Afghanistan   T20I    Dubai(DSC)  2022  Lose   Batting        Win

# %% [markdown]
# Q12 Display  result of winner by each team

# %%
df[df['Result'].str.contains("Win")]
# Out:
#           Team     Opponent Format        Ground  Year  Toss Selection Result
# 1    Sri Lanka     Pakistan    ODI       Sharjah  1984   Win   Bowling    Win
# 2        India    Sri Lanka    ODI       Sharjah  1984   Win   Bowling    Win
# 4        India     Pakistan    ODI       Sharjah  1984   Win   Batting    Win
# 7     Pakistan    Sri Lanka    ODI  Colombo(PSS)  1986  Lose   Batting    Win
# 9     Pakistan   Bangladesh    ODI      Moratuwa  1986   Win   Bowling    Win
# ..         ...          ...    ...           ...   ...   ...       ...    ...
# 245  Sri Lanka        India   T20I    Dubai(DSC)  2022   Win   Bowling    Win
# 247   Pakistan  Afghanistan   T20I       Sharjah  2022   Win   Bowling    Win
# 249      India  Afghanistan   T20I    Dubai(DSC)  2022  Lose   Batting    Win
# 251  Sri Lanka     Pakistan   T20I    Dubai(DSC)  2022   Win   Bowling    Win
# 253  Sri Lanka     Pakistan   T20I    Dubai(DSC)  2022  Lose   Batting    Win
#
# [124 rows x 8 columns]

# %%
#we can observe that there are 124 rows of data and 8 columns,winner by each team:

# %% [markdown]
# Q13.Display All Oppnent team  of India:

# %%
df[df['Opponent'].str.contains("India")]
# Out:
#             Team Opponent Format        Ground  Year  Toss Selection  \
# 3      Sri Lanka    India    ODI       Sharjah  1984  Lose   Batting
# 5       Pakistan    India    ODI       Sharjah  1984  Lose   Bowling
# 187     Pakistan    India   T20I        Mirpur  2016  Lose   Batting
# 193    Sri Lanka    India   T20I        Mirpur  2016  Lose   Batting
# 197          UAE    India   T20I        Mirpur  2016   Win   Batting
# 200   Bangladesh    India   T20I        Mirpur  2016  Lose   Batting
# 208    Hong Kong    India    ODI    Dubai(DSC)  2018   Win   Bowling
# 211     Pakistan    India    ODI    Dubai(DSC)  2018   Win   Batting
# 214   Bangladesh    India    ODI    Dubai(DSC)  2018  Lose   Batting
# 219     Pakistan    India    ODI    Dubai(DSC)  2018   Win   Batting
# 222  Afghanistan    India    ODI    Dubai(DSC)  2018   Win   Batting
# 226   Bangladesh    India    ODI    Dubai(DSC)  2018  Lose   Batting
# 231     Pakistan    India   T20I    Dubai(DSC)  2022  Lose   Batting
# 234    Hong Kong    India   T20I    Dubai(DSC)  2022   Win   Bowling
# 243     Pakistan    India   T20I    Dubai(DSC)  2022   Win   Bowling
# 245    Sri Lanka    India   T20I    Dubai(DSC)  2022   Win   Bowling
# 248  Afghanistan    India   T20I    Dubai(DSC)  2022   Win   Bowling
#
#         Result
# 3         Lose
# 5         Lose
# 16        Lose
# 19         Win
# 23        Lose
# 27        Lose
# 29        Lose
# 31         Win
# 35        Lose
# 36        Lose
# 41         Win
# 45        Lose
# 49        Lose
# 54         Win
# 57   No Result
# 60        Lose
# 62         Win
# 66        Lose
# 69         Win
# 73         Win
# 81        Lose
# 88         Win
# 90        Lose
# 97         Win
# 98        Lose
# 102        Win
# 110       Lose
# 112       Lose
# 116       Lose
# 122        Win
# 125       Lose
# 129        Win
# 132       Lose
# 137       Lose
# 140        Win
# 142       Lose
# 147       Lose
# 150        Win
# 153       Lose
# 160       Lose
# 165        Win
# 169        Win
# 174       Lose
# 180       Lose
# 187       Lose
# 193       Lose
# 197       Lose
# 200       Lose
# 208       Lose
# 211       Lose
# 214       Lose
# 219       Lose
# 222  No Result
# 226       Lose
# 231       Lose
# 234       Lose
# 243        Win
# 245        Win
# 248       Lose

# %%
#we can observe that,there are two many team played againt india:

# %%
cat_col
# Out:
# Index(['Team', 'Opponent', 'Format', 'Ground', 'Toss', 'Selection', 'Result'], dtype='object')

# %% [markdown]
# Q14 Create Count for Format column

# %%
sns.countplot(x=df['Format'])
plt.show()

# %%
# We can observe that there are more number of ODI mathes played

# %% [markdown]
# Q15 Create a pairplot for the given dataset.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Q16.Create Countplot for Team Column

# %%
sns.countplot(x=df['Team'])
plt.xticks(rotation=90)
plt.show()

# %%
#we can observe that srilanka  and india almost win most number of mathes:

# %%
cat_col
# Out:
# Index(['Team', 'Opponent', 'Format', 'Ground', 'Toss', 'Selection', 'Result'], dtype='object')

# %% [markdown]
# Q17 Create Sctterplot Between Team and Result

# %%
sns.scatterplot(x=df['Team'],y=df['Result'],c='orange')
plt.show()
